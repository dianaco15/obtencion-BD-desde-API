# %%
import requests
import time
import requests
import json
import os

##url = 'http://localhost:3000/api/matches/?select=id_fixture&paginate[page]=1&paginate[limit]=3'

url = 'http://localhost:3000/api/matches/?select=id_fixture'
response = requests.get(url)
x = response.json()

def extraccion(record):
    return str(record["id_fixture"])

# Assuming x["data"] is a list of dictionaries
if "data" in x:
    ids = list(map(extraccion, x["data"]))
    #print(ids)
else:
    print("No 'data' key found in the response.")
    
#print('* * * * **  ORIGINAL ', len(ids))    
    
url_exists = 'http://localhost:3000/api/events-fixtures/?select=parameters.fixture'
response_exits = requests.get(url_exists)
x_exists = response_exits.json()


def extraccion_exist (record):
    parameters=record["parameters"]
    return str(parameters["fixture"])

# Assuming x["data"] is a list of dictionaries
if "data" in x_exists:
    ids_exist = list(map(extraccion_exist, x_exists["data"]))
    #print('** * * * * * EXISTENTES',ids_exist, len(ids_exist))
else:
    print("No 'data' key found in the response.")

    
def elementos_faltantes(array1, array2):
    faltantes = []
    for id in array1:
        if(id not in array2):
            
            faltantes.append(id)
    return faltantes  
    

ids_completar= elementos_faltantes( ids,ids_exist)
print("******** COMPLETAR", ids_completar, len(ids_completar))
# Out:
# ******** COMPLETAR ['208377', '208378', '208379', '208380', '208381', '208382', '208383', '208384', '208385', '208386', '208387', '208388', '208389', '208390', '208391', '208392', '208393', '208394', '208395', '208396', '208397', '208398', '208399', '208400', '208401', '208402', '208403', '208404', '208405', '208406', '208407', '208408', '208409', '208410', '208411', '208412', '208413', '208414', '208415', '208416', '208417', '208418', '208419', '208420', '208421', '208422', '208423', '208424', '208425', '208426', '208427', '208428', '208429', '208430', '208431', '208432', '208433', '208434', '208435', '208436', '208437', '208438', '208439', '208440', '208313', '208314', '208315', '208316', '208317', '208318', '208319', '208320', '208321', '208322', '208323', '208324', '208325', '208326', '208327', '208328', '208329', '208330', '208331', '208332', '208333', '208334', '208335', '208336', '208337', '208338', '208339', '208340', '208341', '208342', '208343', '208344', '208345', '208346', '208347', '208348', '208349', '208350', '208351', '208352', '208353', '208354', '208355', '208356', '208357', '208358', '208359', '208360', '208361', '208362', '208363', '208364', '208365', '208366', '208367', '208368', '208369', '208370', '208371', '208372', '208373', '208374', '208375', '208376', '135761', '135762', '135763', '135764', '135765', '135766', '135767', '135768', '135769', '135770', '135771', '135772', '135773', '135774', '135775', '135776', '135777', '135778', '135779', '135780', '135781', '135782', '135783', '135784', '135785', '135786', '135787', '135788', '135789', '135790', '135791', '135792', '135793', '135794', '135795', '135796', '135797', '135798', '135799', '135800', '135801', '135802', '135803', '135804', '135805', '135806', '135807', '135808', '135809', '135810', '135811', '135812', '135813', '135814', '135815', '135816', '135817', '135818', '135819', '135820', '135821', '135822', '135823', '135824', '855734', '855735', '855736', '855737', '855738', '855739', '855740', '855741', '855742', '855743', '855744', '855745', '855746', '855747', '855748', '855749', '855750', '855751', '855752', '855753', '855754', '855755', '855756', '855757', '855758', '855759', '855760', '855761', '855762', '855763', '855764', '855765', '855766', '855767', '855768', '855769', '855770', '855771', '855772', '866681', '866682', '866683', '871850', '871851', '871852', '871853', '871854', '871855', '976533', '976534', '976642', '976643', '977344', '977345', '977705', '977706', '977794', '978036', '978072', '978088', '978279', '978488', '979138', '979139', '121009', '121010', '121011', '121012', '121013', '121014', '121015', '121016', '121017', '121018', '121019', '121020', '121021', '121022', '121023', '121024', '121025', '121026', '121027', '121028', '121029', '121030', '121031', '121032', '121033', '121034', '121035', '121036', '121037', '121038', '121039', '121040', '121041', '121042', '121043', '121044', '159735', '165486', '165487', '165488', '165489', '165490', '165491', '165492', '165774', '167194', '167195', '169551', '169692', '170113', '182888', '182889', '1013552', '1013553', '1013554', '1013555', '1013556', '1013557', '1013558', '1013559', '1013560', '1013561', '1013562', '1013563', '1013564', '1013565', '1013566', '1013567', '1013568', '1013569', '1013570', '1013571', '1013572', '1013573', '1013574', '1013575', '1013576', '1013577', '1013578', '1013579', '1013580', '1013581', '1013582', '1013583', '1013584', '1013585', '1013586', '1013587', '1013588', '1013589', '1013590', '1013591', '1013592', '1013593', '1013594', '1013595', '1013596', '1013597', '1013598', '1013599', '1102768', '1102769', '1102838', '1102839', '1104375', '1104376', '1106509', '1106510', '1108402', '1113421', '1113788', '1113789', '1116446', '1117328', '1119622', '1119623', '355171', '355172', '355173', '355174', '355175', '355176', '355177', '355178', '355179', '355180', '355181', '355182', '355183', '355184', '355185', '355186', '355187', '355188', '355189', '35519 ...

# %%
import requests
import json
import time

url_base = "https://api-football-v1.p.rapidapi.com/v3/fixtures/events"

payload = {}
headers = {
  'x-rapidapi-key': '0ca96789d6mshda4e3b9ef6dd673p13ae8ejsn1051cdd724e9',
  'x-rapidapi-host': 'api-football-v1.p.rapidapi.com'
}

# %%
import os
# URL de la API donde se enviarán los datos
post_url = 'http://localhost:3000/api/events-fixtures/'

# Obtener la ruta del archivo actual
current_directory = os.getcwd()

# Iterar a través de los partidos desde 143579 hasta 1200844
for fixture in ids_completar:
    
    
    
    
    # Construir la URL con los parámetros adecuados
    url = f"{url_base}?fixture={fixture}"
    
    # Hacer la solicitud
    response = requests.get(url, headers=headers)
    
    # Verificar si la solicitud fue exitosa
    if response.status_code == 200:
        data = response.json()
        
        # Guardar la respuesta en un archivo JSON independiente
        #file_name = f"events_fixture_{fixture}.json"
       # file_path = os.path.join(current_directory, file_name)
        #with open(file_path, 'w') as json_file:
         #   json.dump(data, json_file, indent=4)
        
        #print(f"Datos guardados para fixture {fixture} en {file_path}")
        
        # Enviar los datos a la API especificada
        post_response = requests.post(post_url, json=data)
        
        # Verificar si el POST fue exitoso
        if post_response.status_code == 200:  # Usualmente 201 para creación exitosa
            print(f"Datos enviados exitosamente para fixture {fixture} a la API.")
        else:
            print(f"Error al enviar datos para fixture {fixture} a la API: {post_response.status_code} - {post_response.text}")
    else:
        print(f"Error al obtener datos para fixture {fixture}: {response.status_code} - {response.text}")
    
    time.sleep(1)  # Adding a delay to avoid hitting rate limits
# Out:
# Datos enviados exitosamente para fixture 208377 a la API.
# Datos enviados exitosamente para fixture 208378 a la API.
# Datos enviados exitosamente para fixture 208379 a la API.
# Datos enviados exitosamente para fixture 208380 a la API.
# Datos enviados exitosamente para fixture 208381 a la API.
# Datos enviados exitosamente para fixture 208382 a la API.
# Datos enviados exitosamente para fixture 208383 a la API.
# Datos enviados exitosamente para fixture 208384 a la API.
# Datos enviados exitosamente para fixture 208385 a la API.
# Datos enviados exitosamente para fixture 208386 a la API.
# Datos enviados exitosamente para fixture 208387 a la API.
# Datos enviados exitosamente para fixture 208388 a la API.
# Datos enviados exitosamente para fixture 208389 a la API.
# Datos enviados exitosamente para fixture 208390 a la API.
# Datos enviados exitosamente para fixture 208391 a la API.
# Datos enviados exitosamente para fixture 208392 a la API.
# Datos enviados exitosamente para fixture 208393 a la API.
# Datos enviados exitosamente para fixture 208394 a la API.
# Datos enviados exitosamente para fixture 208395 a la API.
# Datos enviados exitosamente para fixture 208396 a la API.
# Datos enviados exitosamente para fixture 208397 a la API.
# Datos enviados exitosamente para fixture 208398 a la API.
# Datos enviados exitosamente para fixture 208399 a la API.
# Datos enviados exitosamente para fixture 208400 a la API.
# Datos enviados exitosamente para fixture 208401 a la API.
# Datos enviados exitosamente para fixture 208402 a la API.
# Datos enviados exitosamente para fixture 208403 a la API.
# Datos enviados exitosamente para fixture 208404 a la API.
# Datos enviados exitosamente para fixture 208405 a la API.
# Datos enviados exitosamente para fixture 208406 a la API.
# Datos enviados exitosamente para fixture 208407 a la API.
# Datos enviados exitosamente para fixture 208408 a la API.
# Datos enviados exitosamente para fixture 208409 a la API.
# Datos enviados exitosamente para fixture 208410 a la API.
# Datos enviados exitosamente para fixture 208411 a la API.
# Datos enviados exitosamente para fixture 208412 a la API.
# Datos enviados exitosamente para fixture 208413 a la API.
# Datos enviados exitosamente para fixture 208414 a la API.
# Datos enviados exitosamente para fixture 208415 a la API.
# Datos enviados exitosamente para fixture 208416 a la API.
# Datos enviados exitosamente para fixture 208417 a la API.
# Datos enviados exitosamente para fixture 208418 a la API.
# Datos enviados exitosamente para fixture 208419 a la API.
# Datos enviados exitosamente para fixture 208420 a la API.
# Datos enviados exitosamente para fixture 208421 a la API.
# Datos enviados exitosamente para fixture 208422 a la API.
# Datos enviados exitosamente para fixture 208423 a la API.
# Datos enviados exitosamente para fixture 208424 a la API.
# Datos enviados exitosamente para fixture 208425 a la API.
# Datos enviados exitosamente para fixture 208426 a la API.
# Datos enviados exitosamente para fixture 208427 a la API.
# Datos enviados exitosamente para fixture 208428 a la API.
# Datos enviados exitosamente para fixture 208429 a la API.
# Datos enviados exitosamente para fixture 208430 a la API.
# Datos enviados exitosamente para fixture 208431 a la API.
# Datos enviados exitosamente para fixture 208432 a la API.
# Datos enviados exitosamente para fixture 208433 a la API.
# Datos enviados exitosamente para fixture 208434 a la API.
# Datos enviados exitosamente para fixture 208435 a la API.
# Datos enviados exitosamente para fixture 208436 a la API.
# Datos enviados exitosamente para fixture 208437 a la API.
# Datos enviados exitosamente para fixture 208438 a la API.
# Datos enviados exitosamente para fixture 208439 a la API.
# Datos enviados exitosamente para fixture 208440 a la API.
# Datos enviados exitosamente para fixture 208313 a la API.
# Datos enviados exitosamente para fixture 208314 a la API.
# Datos enviados exitosamente para fixture 208315 a la API.
# Datos enviados exitosamente para fixture 208316 a la API.
# Datos enviados exitosamente para fixture 208317 a la API.
# Datos enviados exitosamente para fixture 208318 a la API.
# Datos enviados exitosamente para fixture 208319 a la API.
# Datos enviados exitosamente para fixture 208320 a la API.
# Datos enviados exitosamente para fixture 208321 a la API.
# Datos enviados exitosamente para fixture 208322 a la API.
# Datos enviados exitosamente para fixture 208323 a la API.
# Datos enviados exitosamente para fixture 208324 a la API.
# Datos enviados exitosamente para fixture 208325 a la API.
# Datos enviados exitosamente para fixture 208326 a la API.
# Datos enviados exitosamente para fixture 208327 a la API.
# Datos enviados exitosamente para fixture 208328 a la API.
# Datos enviados exitosamente para fixture 208329 a la API.
# Datos enviados exitosamente para fixture 208330 a la API.
# Datos enviados exitosamente para fixture 208331 a la API.
# Datos enviados exitosamente para fixture 208332 a la API.
# Datos enviados exitosamente para fixture 208333 a la API.
# Datos enviados exitosamente para fixture 208334 a la API.
# Datos enviados exitosamente para fixture 208335 a la API.
# Datos enviados exitosamente para fixture 208336 a la API.
# Datos enviados exitosamente para fixture 208337 a la API.
# Datos enviados exitosamente para fixture 208338 a la API.
# Datos enviados exitosamente para fixture 208339 a la API.
# Datos enviados exitosamente para fixture 208340 a la API.
# Datos enviados exitosamente para fixture 208341 a la API.
# Datos enviados exitosamente para fixture 208342 a la API.
# Datos enviados exitosamente para fixture 208343 a la API.
# Datos enviados exitosamente para fixture 208344 a la API.
# Datos enviados exitosamente para fixture 208345 a la API.
# Datos enviados exitosamente para fixture 208346 a la API.
# Datos enviados exitosamente para fixture 208347 a la API.
# Datos enviados exitosamente para fixture 208348 a la API.
# Datos enviados exitosamente para fixture 208349 a la API.
# Datos enviados exitosamente para fixture 208350 a la API.
# Datos enviados exitosamente para fixture 208351 a la API.
# Datos enviados exitosamente para fixture 208352 a la API.
# Datos enviados exitosamente para fixture 208353 a la API.
# Datos enviados exitosamente para fixture 208354 a la API.
# Datos enviados exitosamente para fixture 208355 a la API.
# Datos enviados exitosamente para fixture 208356 a la API.
# Datos enviados exitosamente para fixture 208357 a la API.
# Datos enviados exitosamente para fixture 208358 a la API.
# Datos enviados exitosamente para fixture 208359 a la API.
# Datos enviados exitosamente para fixture 208360 a la API.
# Datos enviados exitosamente para fixture 208361 a la API.
# Datos enviados exitosamente para fixture 208362 a la API.
# Datos enviados exitosamente para fixture 208363 a la API.
# Datos enviados exitosamente para fixture 208364 a la API.
# Datos enviados exitosamente para fixture 208365 a la API.
# Datos enviados exitosamente para fixture 208366 a la API.
# Datos enviados exitosamente para fixture 208367 a la API.
# Datos enviados exitosamente para fixture 208368 a la API.
# Datos enviados exitosamente para fixture 208369 a la API.
# Datos enviados exitosamente para fixture 208370 a la API.
# Datos enviados exitosamente para fixture 208371 a la API.
# Datos enviados exitosamente para fixture 208372 a la API.
# Datos enviados exitosamente para fixture 208373 a la API.
# Datos enviados exitosamente para fixture 208374 a la API.
# Datos enviados exitosamente para fixture 208375 a la API.
# Datos enviados exitosamente para fixture 208376 a la API.
# Datos enviados exitosamente para fixture 135761 a la API.
# Datos enviados exitosamente para fixture 135762 a la API.
# Datos enviados exitosamente para fixture 135763 a la API.
# Datos enviados exitosamente para fixture 135764 a la API.
# Datos enviados exitosamente para fixture 135765 a la API.
# Datos enviados exitosamente para fixture 135766 a la API.
# Datos enviados exitosamente para fixture 135767 a la API.
# Datos enviados exitosamente para fixture 135768 a la API.
# Datos enviados exitosamente para fixture 135769 a la API.
# Datos enviados exitosamente para fixture 135770 a la API.
# Datos enviados exitosamente para fixture 135771 a la API.
# Datos enviados exitosamente para fixture 135772 a la API.
# Datos enviados exitosamente para fixture 135773 a la API.
# Datos enviados exitosamente para fixture 135774 a la API.
# Datos enviados exitosamente para fixture 135775 a la API.
# Datos enviados exitosamente para fixture 135776 a la API.
# Datos enviados exitosamente para fixture 135777 a la API.
# Datos enviados exitosamente para fixture 135778 a la API.
# Datos enviados exitosamente para fixture 135779 a la API.
# Datos enviados exitosamente para fixture 135780 a la API.
# Datos enviados exitosamente para fixture 135781 a la API.
# Datos enviados exitosamente para fixture 135782 a la API.
# Datos enviados exitosamente para fixture 135783 a la API.
# Datos enviados exitosamente para fixture 135784 a la API.
# Datos enviados exitosamente para fixture 135785 a la API.
# Datos enviados exitosamente para fixture 135786 a la API.
# Datos enviados exitosamente para fixture 135787 a la API.
# Datos enviados exitosamente para fixture 135788 a la API.
# Datos enviados exitosamente para fixture 135789 a la API.
# Datos enviados exitosamente para fixture 135790 a la API.
# Datos enviados exitosamente para fixture 135791 a la API.
# Datos enviados exitosamente para fixture 135792 a la API.
# Datos enviados exitosamente para fixture 135793 a la API.
# Datos enviados exitosamente para fixture 135794 a la API.
# Datos enviados exitosamente para fixture 135795 a la API.
# Datos enviados exitosamente para fixture 135796 a la API.
# Datos enviados exitosamente para fixture 135797 a la API.
# Datos enviados exitosamente para fixture 135798 a la API.
# Datos enviados exitosamente para fixture 135799 a la API.
# Datos enviados exitosamente para fixture 135800 a la API.
# Datos enviados exitosamente para fixture 135801 a la API.
# Datos enviados exitosamente para fixture 135802 a la API.
# Datos enviados exitosamente para fixture 135803 a la API.
# Datos enviados exitosamente para fixture 135804 a la API.
# Datos enviados exitosamente para fixture 135805 a la API.
# Datos enviados exitosamente para fixture 135806 a la API.
# Datos enviados exitosamente para fixture 135807 a la API.
# Datos enviados exitosamente para fixture 135808 a la API.
# Datos enviados exitosamente para fixture 135809 a la API.
# Datos enviados exitosamente para fixture 135810 a la API.
# Datos enviados exitosamente para fixture 135811 a la API.
# Datos enviados exitosamente para fixture 135812 a la API.
# Datos enviados exitosamente para fixture 135813 a la API.
# Datos enviados exitosamente para fixture 135814 a la API.
# Datos enviados exitosamente para fixture 135815 a la API.
# Datos enviados exitosamente para fixture 135816 a la API.
# Datos enviados exitosamente para fixture 135817 a la API.
# Datos enviados exitosamente para fixture 135818 a la API.
# Datos enviados exitosamente para fixture 135819 a la API.
# Datos enviados exitosamente para fixture 135820 a la API.
# Datos enviados exitosamente para fixture 135821 a la API.
# Datos enviados exitosamente para fixture 135822 a la API.
# Datos enviados exitosamente para fixture 135823 a la API.
# Datos enviados exitosamente para fixture 135824 a la API.
# Datos enviados exitosamente para fixture 855734 a la API.
# Datos enviados exitosamente para fixture 855735 a la API.
# Datos enviados exitosamente para fixture 855736 a la API.
# Datos enviados exitosamente para fixture 855737 a la API.
# Datos enviados exitosamente para fixture 855738 a la API.
# Datos enviados exitosamente para fixture 855739 a la API.
# Datos enviados exitosamente para fixture 855740 a la API.
# Datos enviados exitosamente para fixture 855741 a la API.
# Datos enviados exitosamente para fixture 855742 a la API.
# Datos enviados exitosamente para fixture 855743 a la API.
# Datos enviados exitosamente para fixture 855744 a la API.
# Datos enviados exitosamente para fixture 855745 a la API.
# Datos enviados exitosamente para fixture 855746 a la API.
# Datos enviados exitosamente para fixture 855747 a la API.
# Datos enviados exitosamente para fixture 855748 a la API.
# Datos enviados exitosamente para fixture 855749 a la API.
# Datos enviados exitosamente para fixture 855750 a la API.
# Datos enviados exitosamente para fixture 855751 a la API.
# Datos enviados exitosamente para fixture 855752 a la API.
# Datos enviados exitosamente para fixture 855753 a la API.
# Datos enviados exitosamente para fixture 855754 a la API.
# Datos enviados exitosamente para fixture 855755 a la API.
# Datos enviados exitosamente para fixture 855756 a la API.
# Datos enviados exitosamente para fixture 855757 a la API.
# Datos enviados exitosamente para fixture 855758 a la API.
# Datos enviados exitosamente para fixture 855759 a la API.
# Datos enviados exitosamente para fixture 855760 a la API.
# Datos enviados exitosamente para fixture 855761 a la API.
# Datos enviados exitosamente para fixture 855762 a la API.
# Datos enviados exitosamente para fixture 855763 a la API.
# Datos enviados exitosamente para fixture 855764 a la API.
# Datos enviados exitosamente para fixture 855765 a la API.
# Datos enviados exitosamente para fixture 855766 a la API.
# Datos enviados exitosamente para fixture 855767 a la API.
# Datos enviados exitosamente para fixture 855768 a la API.
# Datos enviados exitosamente para fixture 855769 a la API.
# Datos enviados exitosamente para fixture 855770 a la API.
# Datos enviados exitosamente para fixture 855771 a la API.
# Datos enviados exitosamente para fixture 855772 a la API.
# Datos enviados exitosamente para fixture 866681 a la API.
# Datos enviados exitosamente para fixture 866682 a la API.
# Datos enviados exitosamente para fixture 866683 a la API.
# Datos enviados exitosamente para fixture 871850 a la API.
# Datos enviados exitosamente para fixture 871851 a la API.
# Datos enviados exitosamente para fixture 871852 a la API.
# Datos enviados exitosamente para fixture 871853 a la API.
# Datos enviados exitosamente para fixture 871854 a la API.
# Datos enviados exitosamente para fixture 871855 a la API.
# Datos enviados exitosamente para fixture 976533 a la API.
# Datos enviados exitosamente para fixture 976534 a la API.
# Datos enviados exitosamente para fixture 976642 a la API.
# Datos enviados exitosamente para fixture 976643 a la API.
# Datos enviados exitosamente para fixture 977344 a la API.
# Datos enviados exitosamente para fixture 977345 a la API.
# Datos enviados exitosamente para fixture 977705 a la API.
# Datos enviados exitosamente para fixture 977706 a la API.
# Datos enviados exitosamente para fixture 977794 a la API.
# Datos enviados exitosamente para fixture 978036 a la API.
# Datos enviados exitosamente para fixture 978072 a la API.
# Datos enviados exitosamente para fixture 978088 a la API.
# Datos enviados exitosamente para fixture 978279 a la API.
# Datos enviados exitosamente para fixture 978488 a la API.
# Datos enviados exitosamente para fixture 979138 a la API.
# Datos enviados exitosamente para fixture 979139 a la API.
# Datos enviados exitosamente para fixture 121009 a la API.
# Datos enviados exitosamente para fixture 121010 a la API.
# Datos enviados exitosamente para fixture 121011 a la API.
# Datos enviados exitosamente para fixture 121012 a la API.
# Datos enviados exitosamente para fixture 121013 a la API.
# Datos enviados exitosamente para fixture 121014 a la API.
# Datos enviados exitosamente para fixture 121015 a la API.
# Datos enviados exitosamente para fixture 121016 a la API.
# Datos enviados exitosamente para fixture 121017 a la API.
# Datos enviados exitosamente para fixture 121018 a la API.
# Datos enviados exitosamente para fixture 121019 a la API.
# Datos enviados exitosamente para fixture 121020 a la API.
# Datos enviados exitosamente para fixture 121021 a la API.
# Datos enviados exitosamente para fixture 121022 a la API.
# Datos enviados exitosamente para fixture 121023 a la API.
# Datos enviados exitosamente para fixture 121024 a la API.
# Datos enviados exitosamente para fixture 121025 a la API.
# Datos enviados exitosamente para fixture 121026 a la API.
# Datos enviados exitosamente para fixture 121027 a la API.
# Datos enviados exitosamente para fixture 121028 a la API.
# Datos enviados exitosamente para fixture 121029 a la API.
# Datos enviados exitosamente para fixture 121030 a la API.
# Datos enviados exitosamente para fixture 121031 a la API.
# Datos enviados exitosamente para fixture 121032 a la API.
# Datos enviados exitosamente para fixture 121033 a la API.
# Datos enviados exitosamente para fixture 121034 a la API.
# Datos enviados exitosamente para fixture 121035 a la API.
# Datos enviados exitosamente para fixture 121036 a la API.
# Datos enviados exitosamente para fixture 121037 a la API.
# Datos enviados exitosamente para fixture 121038 a la API.
# Datos enviados exitosamente para fixture 121039 a la API.
# Datos enviados exitosamente para fixture 121040 a la API.
# Datos enviados exitosamente para fixture 121041 a la API.
# Datos enviados exitosamente para fixture 121042 a la API.
# Datos enviados exitosamente para fixture 121043 a la API.
# Datos enviados exitosamente para fixture 121044 a la API.
# Datos enviados exitosamente para fixture 159735 a la API.
# Datos enviados exitosamente para fixture 165486 a la API.
# Datos enviados exitosamente para fixture 165487 a la API.
# Datos enviados exitosamente para fixture 165488 a la API.
# Datos enviados exitosamente para fixture 165489 a la API.
# Datos enviados exitosamente para fixture 165490 a la API.
# Datos enviados exitosamente para fixture 165491 a la API.
# Datos enviados exitosamente para fixture 165492 a la API.
# Datos enviados exitosamente para fixture 165774 a la API.
# Datos enviados exitosamente para fixture 167194 a la API.
# Datos enviados exitosamente para fixture 167195 a la API.
# Datos enviados exitosamente para fixture 169551 a la API.
# Datos enviados exitosamente para fixture 169692 a la API.
# Datos enviados exitosamente para fixture 170113 a la API.
# Datos enviados exitosamente para fixture 182888 a la API.
# Datos enviados exitosamente para fixture 182889 a la API.
# Datos enviados exitosamente para fixture 1013552 a la API.
# Datos enviados exitosamente para fixture 1013553 a la API.
# Datos enviados exitosamente para fixture 1013554 a la API.
# Datos enviados exitosamente para fixture 1013555 a la API.
# Datos enviados exitosamente para fixture 1013556 a la API.
# Datos enviados exitosamente para fixture 1013557 a la API.
# Datos enviados exitosamente para fixture 1013558 a la API.
# Datos enviados exitosamente para fixture 1013559 a la API.
# Datos enviados exitosamente para fixture 1013560 a la API.
# Datos enviados exitosamente para fixture 1013561 a la API.
# Datos enviados exitosamente para fixture 1013562 a la API.
# Datos enviados exitosamente para fixture 1013563 a la API.
# Datos enviados exitosamente para fixture 1013564 a la API.
# Datos enviados exitosamente para fixture 1013565 a la API.
# Datos enviados exitosamente para fixture 1013566 a la API.
# Datos enviados exitosamente para fixture 1013567 a la API.
# Datos enviados exitosamente para fixture 1013568 a la API.
# Datos enviados exitosamente para fixture 1013569 a la API.
# Datos enviados exitosamente para fixture 1013570 a la API.
# Datos enviados exitosamente para fixture 1013571 a la API.
# Datos enviados exitosamente para fixture 1013572 a la API.
# Datos enviados exitosamente para fixture 1013573 a la API.
# Datos enviados exitosamente para fixture 1013574 a la API.
# Datos enviados exitosamente para fixture 1013575 a la API.
# Datos enviados exitosamente para fixture 1013576 a la API.
# Datos enviados exitosamente para fixture 1013577 a la API.
# Datos enviados exitosamente para fixture 1013578 a la API.
# Datos enviados exitosamente para fixture 1013579 a la API.
# Datos enviados exitosamente para fixture 1013580 a la API.
# Datos enviados exitosamente para fixture 1013581 a la API.
# Datos enviados exitosamente para fixture 1013582 a la API.
# Datos enviados exitosamente para fixture 1013583 a la API.
# Datos enviados exitosamente para fixture 1013584 a la API.
# Datos enviados exitosamente para fixture 1013585 a la API.
# Datos enviados exitosamente para fixture 1013586 a la API.
# Datos enviados exitosamente para fixture 1013587 a la API.
# Datos enviados exitosamente para fixture 1013588 a la API.
# Datos enviados exitosamente para fixture 1013589 a la API.
# Datos enviados exitosamente para fixture 1013590 a la API.
# Datos enviados exitosamente para fixture 1013591 a la API.
# Datos enviados exitosamente para fixture 1013592 a la API.
# Datos enviados exitosamente para fixture 1013593 a la API.
# Datos enviados exitosamente para fixture 1013594 a la API.
# Datos enviados exitosamente para fixture 1013595 a la API.
# Datos enviados exitosamente para fixture 1013596 a la API.
# Datos enviados exitosamente para fixture 1013597 a la API.
# Datos enviados exitosamente para fixture 1013598 a la API.
# Datos enviados exitosamente para fixture 1013599 a la API.
# Datos enviados exitosamente para fixture 1102768 a la API.
# Datos enviados exitosamente para fixture 1102769 a la API.
# Datos enviados exitosamente para fixture 1102838 a la API.
# Datos enviados exitosamente para fixture 1102839 a la API.
# Datos enviados exitosamente para fixture 1104375 a la API.
# Datos enviados exitosamente para fixture 1104376 a la API.
# Datos enviados exitosamente para fixture 1106509 a la API.
# Datos enviados exitosamente para fixture 1106510 a la API.
# Datos enviados exitosamente para fixture 1108402 a la API.
# Datos enviados exitosamente para fixture 1113421 a la API.
# Datos enviados exitosamente para fixture 1113788 a la API.
# Datos enviados exitosamente para fixture 1113789 a la API.
# Datos enviados exitosamente para fixture 1116446 a la API.
# Datos enviados exitosamente para fixture 1117328 a la API.
# Datos enviados exitosamente para fixture 1119622 a la API.
# Datos enviados exitosamente para fixture 1119623 a la API.
# Datos enviados exitosamente para fixture 355171 a la API.
# Datos enviados exitosamente para fixture 355172 a la API.
# Datos enviados exitosamente para fixture 355173 a la API.
# Datos enviados exitosamente para fixture 355174 a la API.
# Datos enviados exitosamente para fixture 355175 a la API.
# Datos enviados exitosamente para fixture 355176 a la API.
# Datos enviados exitosamente para fixture 355177 a la API.
# Datos enviados exitosamente para fixture 355178 a la API.
# Datos enviados exitosamente para fixture 355179 a la API.
# Datos enviados exitosamente para fixture 355180 a la API.
# Datos enviados exitosamente para fixture 355181 a la API.
# Datos enviados exitosamente para fixture 355182 a la API.
# Datos enviados exitosamente para fixture 355183 a la API.
# Datos enviados exitosamente para fixture 355184 a la API.
# Datos enviados exitosamente para fixture 355185 a la API.
# Datos enviados exitosamente para fixture 355186 a la API.
# Datos enviados exitosamente para fixture 355187 a la API.
# Datos enviados exitosamente para fixture 355188 a la API.
# Datos enviados exitosamente para fixture 355189 a la API.
# Datos enviados exitosamente para fixture 355190 a la API.
# Datos enviados exitosamente para fixture 355191 a la API.
# Datos enviados exitosamente para fixture 355192 a la API.
# Datos enviados exitosamente para fixture 355193 a la API.
# Datos enviados exitosamente para fixture 355194 a la API.
# Datos enviados exitosamente para fixture 355195 a la API.
# Datos enviados exitosamente para fixture 355196 a la API.
# Datos enviados exitosamente para fixture 355197 a la API.
# Datos enviados exitosamente para fixture 355198 a la API.
# Datos enviados exitosamente para fixture 355199 a la API.
# Datos enviados exitosamente para fixture 355200 a la API.
# Datos enviados exitosamente para fixture 355201 a la API.
# Datos enviados exitosamente para fixture 355202 a la API.
# Datos enviados exitosamente para fixture 355203 a la API.
# Datos enviados exitosamente para fixture 355204 a la API.
# Datos enviados exitosamente para fixture 355205 a la API.
# Datos enviados exitosamente para fixture 355206 a la API.
# Datos enviados exitosamente para fixture 355207 a la API.
# Datos enviados exitosamente para fixture 355208 a la API.
# Datos enviados exitosamente para fixture 355209 a la API.
# Datos enviados exitosamente para fixture 355210 a la API.
# Datos enviados exitosamente para fixture 355211 a la API.
# Datos enviados exitosamente para fixture 355212 a la API.
# Datos enviados exitosamente para fixture 355213 a la API.
# Datos enviados exitosamente para fixture 355214 a la API.
# Datos enviados exitosamente para fixture 355215 a la API.
# Datos enviados exitosamente para fixture 355216 a la API.
# Datos enviados exitosamente para fixture 355217 a la API.
# Datos enviados exitosamente para fixture 355218 a la API.
# Datos enviados exitosamente para fixture 355219 a la API.
# Datos enviados exitosamente para fixture 355220 a la API.
# Datos enviados exitosamente para fixture 355221 a la API.
# Datos enviados exitosamente para fixture 355222 a la API.
# Datos enviados exitosamente para fixture 355223 a la API.
# Datos enviados exitosamente para fixture 355224 a la API.
# Datos enviados exitosamente para fixture 355225 a la API.
# Datos enviados exitosamente para fixture 355226 a la API.
# Datos enviados exitosamente para fixture 355227 a la API.
# Datos enviados exitosamente para fixture 355228 a la API.
# Datos enviados exitosamente para fixture 355229 a la API.
# Datos enviados exitosamente para fixture 355230 a la API.
# Datos enviados exitosamente para fixture 355231 a la API.
# Datos enviados exitosamente para fixture 355232 a la API.
# Datos enviados exitosamente para fixture 355233 a la API.
# Datos enviados exitosamente para fixture 355234 a la API.
# Datos enviados exitosamente para fixture 355235 a la API.
# Datos enviados exitosamente para fixture 355236 a la API.
# Datos enviados exitosamente para fixture 355237 a la API.
# Datos enviados exitosamente para fixture 355238 a la API.
# Datos enviados exitosamente para fixture 355239 a la API.
# Datos enviados exitosamente para fixture 355240 a la API.
# Datos enviados exitosamente para fixture 355241 a la API.
# Datos enviados exitosamente para fixture 355242 a la API.
# Datos enviados exitosamente para fixture 355243 a la API.
# Datos enviados exitosamente para fixture 355244 a la API.
# Datos enviados exitosamente para fixture 355245 a la API.
# Datos enviados exitosamente para fixture 355246 a la API.
# Datos enviados exitosamente para fixture 355247 a la API.
# Datos enviados exitosamente para fixture 355248 a la API.
# Datos enviados exitosamente para fixture 355249 a la API.
# Datos enviados exitosamente para fixture 355250 a la API.
# Datos enviados exitosamente para fixture 355251 a la API.
# Datos enviados exitosamente para fixture 355252 a la API.
# Datos enviados exitosamente para fixture 355253 a la API.
# Datos enviados exitosamente para fixture 355254 a la API.
# Datos enviados exitosamente para fixture 355255 a la API.
# Datos enviados exitosamente para fixture 355256 a la API.
# Datos enviados exitosamente para fixture 355257 a la API.
# Datos enviados exitosamente para fixture 355258 a la API.
# Datos enviados exitosamente para fixture 355259 a la API.
# Datos enviados exitosamente para fixture 355260 a la API.
# Datos enviados exitosamente para fixture 355261 a la API.
# Datos enviados exitosamente para fixture 355262 a la API.
# Datos enviados exitosamente para fixture 355263 a la API.
# Datos enviados exitosamente para fixture 355264 a la API.
# Datos enviados exitosamente para fixture 355265 a la API.
# Datos enviados exitosamente para fixture 355266 a la API.
# Datos enviados exitosamente para fixture 355267 a la API.
# Datos enviados exitosamente para fixture 355268 a la API.
# Datos enviados exitosamente para fixture 355269 a la API.
# Datos enviados exitosamente para fixture 355270 a la API.
# Datos enviados exitosamente para fixture 355271 a la API.
# Datos enviados exitosamente para fixture 355272 a la API.
# Datos enviados exitosamente para fixture 355273 a la API.
# Datos enviados exitosamente para fixture 355274 a la API.
# Datos enviados exitosamente para fixture 355275 a la API.
# Datos enviados exitosamente para fixture 355276 a la API.
# Datos enviados exitosamente para fixture 355277 a la API.
# Datos enviados exitosamente para fixture 355278 a la API.
# Datos enviados exitosamente para fixture 355279 a la API.
# Datos enviados exitosamente para fixture 355280 a la API.
# Datos enviados exitosamente para fixture 355281 a la API.
# Datos enviados exitosamente para fixture 355282 a la API.
# Datos enviados exitosamente para fixture 355283 a la API.
# Datos enviados exitosamente para fixture 355284 a la API.
# Datos enviados exitosamente para fixture 355285 a la API.
# Datos enviados exitosamente para fixture 355286 a la API.
# Datos enviados exitosamente para fixture 355287 a la API.
# Datos enviados exitosamente para fixture 355288 a la API.
# Datos enviados exitosamente para fixture 355289 a la API.
# Datos enviados exitosamente para fixture 355290 a la API.
# Datos enviados exitosamente para fixture 355291 a la API.
# Datos enviados exitosamente para fixture 355292 a la API.
# Datos enviados exitosamente para fixture 355293 a la API.
# Datos enviados exitosamente para fixture 355294 a la API.
# Datos enviados exitosamente para fixture 355295 a la API.
# Datos enviados exitosamente para fixture 355296 a la API.
# Datos enviados exitosamente para fixture 355297 a la API.
# Datos enviados exitosamente para fixture 355298 a la API.
# Datos enviados exitosamente para fixture 355299 a la API.
# Datos enviados exitosamente para fixture 355300 a la API.
# Datos enviados exitosamente para fixture 355301 a la API.
# Datos enviados exitosamente para fixture 355302 a la API.
# Datos enviados exitosamente para fixture 355303 a la API.
# Datos enviados exitosamente para fixture 355304 a la API.
# Datos enviados exitosamente para fixture 355305 a la API.
# Datos enviados exitosamente para fixture 355306 a la API.
# Datos enviados exitosamente para fixture 355307 a la API.
# Datos enviados exitosamente para fixture 355308 a la API.
# Datos enviados exitosamente para fixture 355309 a la API.
# Datos enviados exitosamente para fixture 355310 a la API.
# Datos enviados exitosamente para fixture 355311 a la API.
# Datos enviados exitosamente para fixture 355312 a la API.
# Datos enviados exitosamente para fixture 355313 a la API.
# Datos enviados exitosamente para fixture 355314 a la API.
# Datos enviados exitosamente para fixture 355315 a la API.
# Datos enviados exitosamente para fixture 355316 a la API.
# Datos enviados exitosamente para fixture 355317 a la API.
# Datos enviados exitosamente para fixture 355318 a la API.
# Datos enviados exitosamente para fixture 355319 a la API.
# Datos enviados exitosamente para fixture 355320 a la API.
# Datos enviados exitosamente para fixture 355321 a la API.
# Datos enviados exitosamente para fixture 355322 a la API.
# Datos enviados exitosamente para fixture 355323 a la API.
# Datos enviados exitosamente para fixture 355324 a la API.
# Datos enviados exitosamente para fixture 355325 a la API.
# Datos enviados exitosamente para fixture 355326 a la API.
# Datos enviados exitosamente para fixture 355327 a la API.
# Datos enviados exitosamente para fixture 355328 a la API.
# Datos enviados exitosamente para fixture 355329 a la API.
# Datos enviados exitosamente para fixture 355330 a la API.
# Datos enviados exitosamente para fixture 355331 a la API.
# Datos enviados exitosamente para fixture 355332 a la API.
# Datos enviados exitosamente para fixture 355333 a la API.
# Datos enviados exitosamente para fixture 355334 a la API.
# Datos enviados exitosamente para fixture 355335 a la API.
# Datos enviados exitosamente para fixture 355336 a la API.
# Datos enviados exitosamente para fixture 355337 a la API.
# Datos enviados exitosamente para fixture 355338 a la API.
# Datos enviados exitosamente para fixture 355339 a la API.
# Datos enviados exitosamente para fixture 355340 a la API.
# Datos enviados exitosamente para fixture 355341 a la API.
# Datos enviados exitosamente para fixture 355342 a la API.
# Datos enviados exitosamente para fixture 355343 a la API.
# Datos enviados exitosamente para fixture 355344 a la API.
# Datos enviados exitosamente para fixture 355345 a la API.
# Datos enviados exitosamente para fixture 355346 a la API.
# Datos enviados exitosamente para fixture 355347 a la API.
# Datos enviados exitosamente para fixture 355348 a la API.
# Datos enviados exitosamente para fixture 355349 a la API.
# Datos enviados exitosamente para fixture 355350 a la API.
# Datos enviados exitosamente para fixture 355351 a la API.
# Datos enviados exitosamente para fixture 355352 a la API.
# Datos enviados exitosamente para fixture 355353 a la API.
# Datos enviados exitosamente para fixture 355354 a la API.
# Datos enviados exitosamente para fixture 355355 a la API.
# Datos enviados exitosamente para fixture 355356 a la API.
# Datos enviados exitosamente para fixture 355357 a la API.
# Datos enviados exitosamente para fixture 355358 a la API.
# Datos enviados exitosamente para fixture 355359 a la API.
# Datos enviados exitosamente para fixture 355360 a la API.
# Datos enviados exitosamente para fixture 355361 a la API.
# Datos enviados exitosamente para fixture 355362 a la API.
# Datos enviados exitosamente para fixture 355363 a la API.
# Datos enviados exitosamente para fixture 355364 a la API.
# Datos enviados exitosamente para fixture 355365 a la API.
# Datos enviados exitosamente para fixture 355366 a la API.
# Datos enviados exitosamente para fixture 355367 a la API.
# Datos enviados exitosamente para fixture 355368 a la API.
# Datos enviados exitosamente para fixture 355369 a la API.
# Datos enviados exitosamente para fixture 355370 a la API.
# Datos enviados exitosamente para fixture 355371 a la API.
# Datos enviados exitosamente para fixture 355372 a la API.
# Datos enviados exitosamente para fixture 355373 a la API.
# Datos enviados exitosamente para fixture 355374 a la API.
# Datos enviados exitosamente para fixture 355375 a la API.
# Datos enviados exitosamente para fixture 355376 a la API.
# Datos enviados exitosamente para fixture 355377 a la API.
# Datos enviados exitosamente para fixture 355378 a la API.
# Datos enviados exitosamente para fixture 355379 a la API.
# Datos enviados exitosamente para fixture 355380 a la API.
# Datos enviados exitosamente para fixture 355381 a la API.
# Datos enviados exitosamente para fixture 355382 a la API.
# Datos enviados exitosamente para fixture 355383 a la API.
# Datos enviados exitosamente para fixture 355384 a la API.
# Datos enviados exitosamente para fixture 355385 a la API.
# Datos enviados exitosamente para fixture 152839 a la API.
# Datos enviados exitosamente para fixture 152840 a la API.
# Datos enviados exitosamente para fixture 152841 a la API.
# Datos enviados exitosamente para fixture 152842 a la API.
# Datos enviados exitosamente para fixture 152843 a la API.
# Datos enviados exitosamente para fixture 152844 a la API.
# Datos enviados exitosamente para fixture 152845 a la API.
# Datos enviados exitosamente para fixture 152846 a la API.
# Datos enviados exitosamente para fixture 152847 a la API.
# Datos enviados exitosamente para fixture 152848 a la API.
# Datos enviados exitosamente para fixture 152849 a la API.
# Datos enviados exitosamente para fixture 152850 a la API.
# Datos enviados exitosamente para fixture 152851 a la API.
# Datos enviados exitosamente para fixture 152852 a la API.
# Datos enviados exitosamente para fixture 152853 a la API.
# Datos enviados exitosamente para fixture 152854 a la API.
# Datos enviados exitosamente para fixture 152855 a la API.
# Datos enviados exitosamente para fixture 152856 a la API.
# Datos enviados exitosamente para fixture 152857 a la API.
# Datos enviados exitosamente para fixture 152858 a la API.
# Datos enviados exitosamente para fixture 152859 a la API.
# Datos enviados exitosamente para fixture 152860 a la API.
# Datos enviados exitosamente para fixture 152861 a la API.
# Datos enviados exitosamente para fixture 152862 a la API.
# Datos enviados exitosamente para fixture 152863 a la API.
# Datos enviados exitosamente para fixture 152864 a la API.
# Datos enviados exitosamente para fixture 152865 a la API.
# Datos enviados exitosamente para fixture 152866 a la API.
# Datos enviados exitosamente para fixture 152867 a la API.
# Datos enviados exitosamente para fixture 152868 a la API.
# Datos enviados exitosamente para fixture 152869 a la API.
# Datos enviados exitosamente para fixture 152870 a la API.
# Datos enviados exitosamente para fixture 152871 a la API.
# Datos enviados exitosamente para fixture 152872 a la API.
# Datos enviados exitosamente para fixture 152873 a la API.
# Datos enviados exitosamente para fixture 152874 a la API.
# Datos enviados exitosamente para fixture 152875 a la API.
# Datos enviados exitosamente para fixture 152876 a la API.
# Datos enviados exitosamente para fixture 152877 a la API.
# Datos enviados exitosamente para fixture 152878 a la API.
# Datos enviados exitosamente para fixture 152879 a la API.
# Datos enviados exitosamente para fixture 152880 a la API.
# Datos enviados exitosamente para fixture 152881 a la API.
# Datos enviados exitosamente para fixture 152882 a la API.
# Datos enviados exitosamente para fixture 152883 a la API.
# Datos enviados exitosamente para fixture 152884 a la API.
# Datos enviados exitosamente para fixture 152885 a la API.
# Datos enviados exitosamente para fixture 152886 a la API.
# Datos enviados exitosamente para fixture 152887 a la API.
# Datos enviados exitosamente para fixture 152888 a la API.
# Datos enviados exitosamente para fixture 152889 a la API.
# Datos enviados exitosamente para fixture 152890 a la API.
# Datos enviados exitosamente para fixture 152891 a la API.
# Datos enviados exitosamente para fixture 152892 a la API.
# Datos enviados exitosamente para fixture 152893 a la API.
# Datos enviados exitosamente para fixture 152894 a la API.
# Datos enviados exitosamente para fixture 152895 a la API.
# Datos enviados exitosamente para fixture 152896 a la API.
# Datos enviados exitosamente para fixture 152897 a la API.
# Datos enviados exitosamente para fixture 152898 a la API.
# Datos enviados exitosamente para fixture 152899 a la API.
# Datos enviados exitosamente para fixture 152900 a la API.
# Datos enviados exitosamente para fixture 152901 a la API.
# Datos enviados exitosamente para fixture 152902 a la API.
# Datos enviados exitosamente para fixture 152903 a la API.
# Datos enviados exitosamente para fixture 152904 a la API.
# Datos enviados exitosamente para fixture 152905 a la API.
# Datos enviados exitosamente para fixture 152906 a la API.
# Datos enviados exitosamente para fixture 152907 a la API.
# Datos enviados exitosamente para fixture 152908 a la API.
# Datos enviados exitosamente para fixture 152909 a la API.
# Datos enviados exitosamente para fixture 152910 a la API.
# Datos enviados exitosamente para fixture 152911 a la API.
# Datos enviados exitosamente para fixture 152912 a la API.
# Datos enviados exitosamente para fixture 152913 a la API.
# Datos enviados exitosamente para fixture 152914 a la API.
# Datos enviados exitosamente para fixture 152915 a la API.
# Datos enviados exitosamente para fixture 152916 a la API.
# Datos enviados exitosamente para fixture 152917 a la API.
# Datos enviados exitosamente para fixture 152918 a la API.
# Datos enviados exitosamente para fixture 152919 a la API.
# Datos enviados exitosamente para fixture 152920 a la API.
# Datos enviados exitosamente para fixture 152921 a la API.
# Datos enviados exitosamente para fixture 152922 a la API.
# Datos enviados exitosamente para fixture 152923 a la API.
# Datos enviados exitosamente para fixture 152924 a la API.
# Datos enviados exitosamente para fixture 152925 a la API.
# Datos enviados exitosamente para fixture 152926 a la API.
# Datos enviados exitosamente para fixture 152927 a la API.
# Datos enviados exitosamente para fixture 152928 a la API.
# Datos enviados exitosamente para fixture 152929 a la API.
# Datos enviados exitosamente para fixture 152930 a la API.
# Datos enviados exitosamente para fixture 152931 a la API.
# Datos enviados exitosamente para fixture 152932 a la API.
# Datos enviados exitosamente para fixture 152933 a la API.
# Datos enviados exitosamente para fixture 152934 a la API.
# Datos enviados exitosamente para fixture 152935 a la API.
# Datos enviados exitosamente para fixture 152936 a la API.
# Datos enviados exitosamente para fixture 152937 a la API.
# Datos enviados exitosamente para fixture 152938 a la API.
# Datos enviados exitosamente para fixture 152939 a la API.
# Datos enviados exitosamente para fixture 152940 a la API.
# Datos enviados exitosamente para fixture 152941 a la API.
# Datos enviados exitosamente para fixture 152942 a la API.
# Datos enviados exitosamente para fixture 152943 a la API.
# Datos enviados exitosamente para fixture 152944 a la API.
# Datos enviados exitosamente para fixture 152945 a la API.
# Datos enviados exitosamente para fixture 152946 a la API.
# Datos enviados exitosamente para fixture 152947 a la API.
# Datos enviados exitosamente para fixture 152948 a la API.
# Datos enviados exitosamente para fixture 152949 a la API.
# Datos enviados exitosamente para fixture 152950 a la API.
# Datos enviados exitosamente para fixture 152951 a la API.
# Datos enviados exitosamente para fixture 152952 a la API.
# Datos enviados exitosamente para fixture 152953 a la API.
# Datos enviados exitosamente para fixture 152954 a la API.
# Datos enviados exitosamente para fixture 152955 a la API.
# Datos enviados exitosamente para fixture 152956 a la API.
# Datos enviados exitosamente para fixture 152957 a la API.
# Datos enviados exitosamente para fixture 152958 a la API.
# Datos enviados exitosamente para fixture 152959 a la API.
# Datos enviados exitosamente para fixture 152960 a la API.
# Datos enviados exitosamente para fixture 152961 a la API.
# Datos enviados exitosamente para fixture 152962 a la API.
# Datos enviados exitosamente para fixture 152963 a la API.
# Datos enviados exitosamente para fixture 152964 a la API.
# Datos enviados exitosamente para fixture 152965 a la API.
# Datos enviados exitosamente para fixture 152966 a la API.
# Datos enviados exitosamente para fixture 152967 a la API.
# Datos enviados exitosamente para fixture 152968 a la API.
# Datos enviados exitosamente para fixture 152969 a la API.
# Datos enviados exitosamente para fixture 152970 a la API.
# Datos enviados exitosamente para fixture 152971 a la API.
# Datos enviados exitosamente para fixture 152972 a la API.
# Datos enviados exitosamente para fixture 152973 a la API.
# Datos enviados exitosamente para fixture 152974 a la API.
# Datos enviados exitosamente para fixture 152975 a la API.
# Datos enviados exitosamente para fixture 152976 a la API.
# Datos enviados exitosamente para fixture 152977 a la API.
# Datos enviados exitosamente para fixture 152978 a la API.
# Datos enviados exitosamente para fixture 152979 a la API.
# Datos enviados exitosamente para fixture 152980 a la API.
# Datos enviados exitosamente para fixture 152981 a la API.
# Datos enviados exitosamente para fixture 152982 a la API.
# Datos enviados exitosamente para fixture 152983 a la API.
# Datos enviados exitosamente para fixture 152984 a la API.
# Datos enviados exitosamente para fixture 152985 a la API.
# Datos enviados exitosamente para fixture 152986 a la API.
# Datos enviados exitosamente para fixture 152987 a la API.
# Datos enviados exitosamente para fixture 152988 a la API.
# Datos enviados exitosamente para fixture 152989 a la API.
# Datos enviados exitosamente para fixture 152990 a la API.
# Datos enviados exitosamente para fixture 152991 a la API.
# Datos enviados exitosamente para fixture 152992 a la API.
# Datos enviados exitosamente para fixture 152993 a la API.
# Datos enviados exitosamente para fixture 152994 a la API.
# Datos enviados exitosamente para fixture 152995 a la API.
# Datos enviados exitosamente para fixture 152996 a la API.
# Datos enviados exitosamente para fixture 152997 a la API.
# Datos enviados exitosamente para fixture 152998 a la API.
# Datos enviados exitosamente para fixture 152999 a la API.
# Datos enviados exitosamente para fixture 153000 a la API.
# Datos enviados exitosamente para fixture 153001 a la API.
# Datos enviados exitosamente para fixture 153002 a la API.
# Datos enviados exitosamente para fixture 153003 a la API.
# Datos enviados exitosamente para fixture 153004 a la API.
# Datos enviados exitosamente para fixture 153005 a la API.
# Datos enviados exitosamente para fixture 153006 a la API.
# Datos enviados exitosamente para fixture 153007 a la API.
# Datos enviados exitosamente para fixture 153008 a la API.
# Datos enviados exitosamente para fixture 153009 a la API.
# Datos enviados exitosamente para fixture 153010 a la API.
# Datos enviados exitosamente para fixture 153011 a la API.
# Datos enviados exitosamente para fixture 153012 a la API.
# Datos enviados exitosamente para fixture 153013 a la API.
# Datos enviados exitosamente para fixture 153014 a la API.
# Datos enviados exitosamente para fixture 153015 a la API.
# Datos enviados exitosamente para fixture 153016 a la API.
# Datos enviados exitosamente para fixture 153017 a la API.
# Datos enviados exitosamente para fixture 153018 a la API.
# Datos enviados exitosamente para fixture 153019 a la API.
# Datos enviados exitosamente para fixture 153020 a la API.
# Datos enviados exitosamente para fixture 153021 a la API.
# Datos enviados exitosamente para fixture 153022 a la API.
# Datos enviados exitosamente para fixture 153023 a la API.
# Datos enviados exitosamente para fixture 153024 a la API.
# Datos enviados exitosamente para fixture 153025 a la API.
# Datos enviados exitosamente para fixture 153026 a la API.
# Datos enviados exitosamente para fixture 153027 a la API.
# Datos enviados exitosamente para fixture 153028 a la API.
# Datos enviados exitosamente para fixture 153029 a la API.
# Datos enviados exitosamente para fixture 153030 a la API.
# Datos enviados exitosamente para fixture 153031 a la API.
# Datos enviados exitosamente para fixture 153032 a la API.
# Datos enviados exitosamente para fixture 153033 a la API.
# Datos enviados exitosamente para fixture 153034 a la API.
# Datos enviados exitosamente para fixture 153035 a la API.
# Datos enviados exitosamente para fixture 153036 a la API.
# Datos enviados exitosamente para fixture 153037 a la API.
# Datos enviados exitosamente para fixture 153038 a la API.
# Datos enviados exitosamente para fixture 153039 a la API.
# Datos enviados exitosamente para fixture 153040 a la API.
# Datos enviados exitosamente para fixture 153041 a la API.
# Datos enviados exitosamente para fixture 153042 a la API.
# Datos enviados exitosamente para fixture 153043 a la API.
# Datos enviados exitosamente para fixture 153044 a la API.
# Datos enviados exitosamente para fixture 153045 a la API.
# Datos enviados exitosamente para fixture 153046 a la API.
# Datos enviados exitosamente para fixture 153047 a la API.
# Datos enviados exitosamente para fixture 153048 a la API.
# Datos enviados exitosamente para fixture 153049 a la API.
# Datos enviados exitosamente para fixture 153050 a la API.
# Datos enviados exitosamente para fixture 153051 a la API.
# Datos enviados exitosamente para fixture 153052 a la API.
# Datos enviados exitosamente para fixture 153053 a la API.
# Datos enviados exitosamente para fixture 153054 a la API.
# Datos enviados exitosamente para fixture 153055 a la API.
# Datos enviados exitosamente para fixture 152620 a la API.
# Datos enviados exitosamente para fixture 152621 a la API.
# Datos enviados exitosamente para fixture 152622 a la API.
# Datos enviados exitosamente para fixture 152623 a la API.
# Datos enviados exitosamente para fixture 152624 a la API.
# Datos enviados exitosamente para fixture 152625 a la API.
# Datos enviados exitosamente para fixture 152626 a la API.
# Datos enviados exitosamente para fixture 152627 a la API.
# Datos enviados exitosamente para fixture 152628 a la API.
# Datos enviados exitosamente para fixture 152629 a la API.
# Datos enviados exitosamente para fixture 152630 a la API.
# Datos enviados exitosamente para fixture 152631 a la API.
# Datos enviados exitosamente para fixture 152632 a la API.
# Datos enviados exitosamente para fixture 152633 a la API.
# Datos enviados exitosamente para fixture 152634 a la API.
# Datos enviados exitosamente para fixture 152635 a la API.
# Datos enviados exitosamente para fixture 152636 a la API.
# Datos enviados exitosamente para fixture 152637 a la API.
# Datos enviados exitosamente para fixture 152638 a la API.
# Datos enviados exitosamente para fixture 152639 a la API.
# Datos enviados exitosamente para fixture 152640 a la API.
# Datos enviados exitosamente para fixture 152641 a la API.
# ...
# Datos enviados exitosamente para fixture 1224010 a la API.
# Datos enviados exitosamente para fixture 1224011 a la API.
# Datos enviados exitosamente para fixture 1224012 a la API.
# Datos enviados exitosamente para fixture 1224013 a la API.
# Datos enviados exitosamente para fixture 1224014 a la API.
# Datos enviados exitosamente para fixture 1224015 a la API.
# Datos enviados exitosamente para fixture 1224016 a la API.
# Datos enviados exitosamente para fixture 1224017 a la API.
# Datos enviados exitosamente para fixture 1224018 a la API.
# Datos enviados exitosamente para fixture 1224019 a la API.
# Datos enviados exitosamente para fixture 1224020 a la API.
# Datos enviados exitosamente para fixture 1224021 a la API.
# Datos enviados exitosamente para fixture 1224022 a la API.
# Datos enviados exitosamente para fixture 1224023 a la API.
# Datos enviados exitosamente para fixture 1224024 a la API.
# Datos enviados exitosamente para fixture 1224025 a la API.
# Datos enviados exitosamente para fixture 1224026 a la API.
# Datos enviados exitosamente para fixture 1224027 a la API.
# Datos enviados exitosamente para fixture 1224028 a la API.
# Datos enviados exitosamente para fixture 1224029 a la API.
# Datos enviados exitosamente para fixture 1224030 a la API.
# Datos enviados exitosamente para fixture 1224031 a la API.
# Datos enviados exitosamente para fixture 1224032 a la API.
# Datos enviados exitosamente para fixture 1224033 a la API.
# Datos enviados exitosamente para fixture 1224034 a la API.
# Datos enviados exitosamente para fixture 1224035 a la API.
# Datos enviados exitosamente para fixture 1224036 a la API.
# Datos enviados exitosamente para fixture 1224037 a la API.
# Datos enviados exitosamente para fixture 1224038 a la API.
# Datos enviados exitosamente para fixture 1224039 a la API.
# Datos enviados exitosamente para fixture 1224040 a la API.
# Datos enviados exitosamente para fixture 1224041 a la API.
# Datos enviados exitosamente para fixture 1224042 a la API.
# Datos enviados exitosamente para fixture 1224043 a la API.
# Datos enviados exitosamente para fixture 1224044 a la API.
# Datos enviados exitosamente para fixture 1224045 a la API.
# Datos enviados exitosamente para fixture 1224046 a la API.
# Datos enviados exitosamente para fixture 1224047 a la API.
# Datos enviados exitosamente para fixture 1224048 a la API.
# Datos enviados exitosamente para fixture 1224049 a la API.
# Datos enviados exitosamente para fixture 1224050 a la API.
# Datos enviados exitosamente para fixture 1224051 a la API.
# Datos enviados exitosamente para fixture 1224052 a la API.
# Datos enviados exitosamente para fixture 1224053 a la API.
# Datos enviados exitosamente para fixture 1224054 a la API.
# Datos enviados exitosamente para fixture 1224055 a la API.
# Datos enviados exitosamente para fixture 1224056 a la API.
# Datos enviados exitosamente para fixture 1224057 a la API.
# Datos enviados exitosamente para fixture 1224058 a la API.
# Datos enviados exitosamente para fixture 1224059 a la API.
# Datos enviados exitosamente para fixture 1224060 a la API.
# Datos enviados exitosamente para fixture 1224061 a la API.
# Datos enviados exitosamente para fixture 1224062 a la API.
# Datos enviados exitosamente para fixture 1224063 a la API.
# Datos enviados exitosamente para fixture 1224064 a la API.
# Datos enviados exitosamente para fixture 1224065 a la API.
# Datos enviados exitosamente para fixture 1224066 a la API.
# Datos enviados exitosamente para fixture 1224067 a la API.
# Datos enviados exitosamente para fixture 1224068 a la API.
# Datos enviados exitosamente para fixture 1224069 a la API.
# Datos enviados exitosamente para fixture 1224070 a la API.
# Datos enviados exitosamente para fixture 1224071 a la API.
# Datos enviados exitosamente para fixture 1224072 a la API.
# Datos enviados exitosamente para fixture 1224073 a la API.
# Datos enviados exitosamente para fixture 1224074 a la API.
# Datos enviados exitosamente para fixture 1224075 a la API.
# Datos enviados exitosamente para fixture 1224076 a la API.
# Datos enviados exitosamente para fixture 1224077 a la API.
# Datos enviados exitosamente para fixture 1224078 a la API.
# Datos enviados exitosamente para fixture 1224079 a la API.
# Datos enviados exitosamente para fixture 1224080 a la API.
# Datos enviados exitosamente para fixture 1224081 a la API.
# Datos enviados exitosamente para fixture 1224082 a la API.
# Datos enviados exitosamente para fixture 1224083 a la API.
# Datos enviados exitosamente para fixture 1224084 a la API.
# Datos enviados exitosamente para fixture 1224085 a la API.
# Datos enviados exitosamente para fixture 1224086 a la API.
# Datos enviados exitosamente para fixture 1224087 a la API.
# Datos enviados exitosamente para fixture 1224088 a la API.
# Datos enviados exitosamente para fixture 1224089 a la API.
# Datos enviados exitosamente para fixture 1224090 a la API.
# Datos enviados exitosamente para fixture 1224091 a la API.
# Datos enviados exitosamente para fixture 1224092 a la API.
# Datos enviados exitosamente para fixture 1224093 a la API.
# Datos enviados exitosamente para fixture 1224094 a la API.
# Datos enviados exitosamente para fixture 1224095 a la API.
# Datos enviados exitosamente para fixture 1224096 a la API.
# Datos enviados exitosamente para fixture 1224097 a la API.
# Datos enviados exitosamente para fixture 1224098 a la API.
# Datos enviados exitosamente para fixture 1224099 a la API.
# Datos enviados exitosamente para fixture 1224100 a la API.
# Datos enviados exitosamente para fixture 1224101 a la API.
# Datos enviados exitosamente para fixture 1224102 a la API.
# Datos enviados exitosamente para fixture 1224103 a la API.
# Datos enviados exitosamente para fixture 1224104 a la API.
# Datos enviados exitosamente para fixture 1224105 a la API.
# Datos enviados exitosamente para fixture 1224106 a la API.
# Datos enviados exitosamente para fixture 1224107 a la API.
# Datos enviados exitosamente para fixture 1224108 a la API.
# Datos enviados exitosamente para fixture 1224109 a la API.
# Datos enviados exitosamente para fixture 1224110 a la API.
# Datos enviados exitosamente para fixture 1224111 a la API.
# Datos enviados exitosamente para fixture 1224112 a la API.
# Datos enviados exitosamente para fixture 1224113 a la API.
# Datos enviados exitosamente para fixture 1224114 a la API.
# Datos enviados exitosamente para fixture 1224115 a la API.
# Datos enviados exitosamente para fixture 1224116 a la API.
# Datos enviados exitosamente para fixture 1224117 a la API.
# Datos enviados exitosamente para fixture 1224118 a la API.
# Datos enviados exitosamente para fixture 1224119 a la API.
# Datos enviados exitosamente para fixture 1224120 a la API.
# Datos enviados exitosamente para fixture 1224121 a la API.
# Datos enviados exitosamente para fixture 1224122 a la API.
# Datos enviados exitosamente para fixture 1224123 a la API.
# Datos enviados exitosamente para fixture 1224124 a la API.
# Datos enviados exitosamente para fixture 1224125 a la API.
# Datos enviados exitosamente para fixture 1224126 a la API.
# Datos enviados exitosamente para fixture 1224127 a la API.
# Datos enviados exitosamente para fixture 1224128 a la API.
# Datos enviados exitosamente para fixture 1224129 a la API.
# Datos enviados exitosamente para fixture 1224130 a la API.
# Datos enviados exitosamente para fixture 1224131 a la API.
# Datos enviados exitosamente para fixture 1224132 a la API.
# Datos enviados exitosamente para fixture 1224133 a la API.
# Datos enviados exitosamente para fixture 1224134 a la API.
# Datos enviados exitosamente para fixture 1224135 a la API.
# Datos enviados exitosamente para fixture 1224136 a la API.
# Datos enviados exitosamente para fixture 1224137 a la API.
# Datos enviados exitosamente para fixture 1224138 a la API.
# Datos enviados exitosamente para fixture 1224139 a la API.
# Datos enviados exitosamente para fixture 1224140 a la API.
# Datos enviados exitosamente para fixture 1224141 a la API.
# Datos enviados exitosamente para fixture 1224142 a la API.
# Datos enviados exitosamente para fixture 1224143 a la API.
# Datos enviados exitosamente para fixture 1224144 a la API.
# Datos enviados exitosamente para fixture 1224145 a la API.
# Datos enviados exitosamente para fixture 1224146 a la API.
# Datos enviados exitosamente para fixture 1224147 a la API.
# Datos enviados exitosamente para fixture 1224148 a la API.
# Datos enviados exitosamente para fixture 1224149 a la API.
# Datos enviados exitosamente para fixture 1224150 a la API.
# Datos enviados exitosamente para fixture 1224151 a la API.
# Datos enviados exitosamente para fixture 1224152 a la API.
# Datos enviados exitosamente para fixture 1224153 a la API.
# Datos enviados exitosamente para fixture 1224154 a la API.
# Datos enviados exitosamente para fixture 1224155 a la API.
# Datos enviados exitosamente para fixture 1224156 a la API.
# Datos enviados exitosamente para fixture 1224157 a la API.
# Datos enviados exitosamente para fixture 1224158 a la API.
# Datos enviados exitosamente para fixture 1224159 a la API.
# Datos enviados exitosamente para fixture 1224160 a la API.
# Datos enviados exitosamente para fixture 1224161 a la API.
# Datos enviados exitosamente para fixture 1224162 a la API.
# Datos enviados exitosamente para fixture 1224163 a la API.
# Datos enviados exitosamente para fixture 1224164 a la API.
# Datos enviados exitosamente para fixture 1224165 a la API.
# Datos enviados exitosamente para fixture 1224166 a la API.
# Datos enviados exitosamente para fixture 1224167 a la API.
# Datos enviados exitosamente para fixture 1224168 a la API.
# Datos enviados exitosamente para fixture 1224169 a la API.
# Datos enviados exitosamente para fixture 1224170 a la API.
# Datos enviados exitosamente para fixture 1224171 a la API.
# Datos enviados exitosamente para fixture 1224172 a la API.
# Datos enviados exitosamente para fixture 1224173 a la API.
# Datos enviados exitosamente para fixture 1224174 a la API.
# Datos enviados exitosamente para fixture 1224175 a la API.
# Datos enviados exitosamente para fixture 1224176 a la API.
# Datos enviados exitosamente para fixture 1224177 a la API.
# Datos enviados exitosamente para fixture 1224178 a la API.
# Datos enviados exitosamente para fixture 1224179 a la API.
# Datos enviados exitosamente para fixture 1224180 a la API.
# Datos enviados exitosamente para fixture 1224181 a la API.
# Datos enviados exitosamente para fixture 1224182 a la API.
# Datos enviados exitosamente para fixture 1224183 a la API.
# Datos enviados exitosamente para fixture 1224184 a la API.
# Datos enviados exitosamente para fixture 1224185 a la API.
# Datos enviados exitosamente para fixture 1224186 a la API.
# Datos enviados exitosamente para fixture 1224187 a la API.
# Datos enviados exitosamente para fixture 1224188 a la API.
# Datos enviados exitosamente para fixture 1224189 a la API.
# Datos enviados exitosamente para fixture 1224190 a la API.
# Datos enviados exitosamente para fixture 1224191 a la API.
# Datos enviados exitosamente para fixture 1224192 a la API.
# Datos enviados exitosamente para fixture 1224193 a la API.
# Datos enviados exitosamente para fixture 1224194 a la API.
# Datos enviados exitosamente para fixture 1224195 a la API.
# Datos enviados exitosamente para fixture 1224196 a la API.
# Datos enviados exitosamente para fixture 1224197 a la API.
# Datos enviados exitosamente para fixture 1224198 a la API.
# Datos enviados exitosamente para fixture 1224199 a la API.
# Datos enviados exitosamente para fixture 1224200 a la API.
# Datos enviados exitosamente para fixture 1224201 a la API.
# Datos enviados exitosamente para fixture 1224202 a la API.
# Datos enviados exitosamente para fixture 1224203 a la API.
# Datos enviados exitosamente para fixture 1224204 a la API.
# Datos enviados exitosamente para fixture 1224205 a la API.
# Datos enviados exitosamente para fixture 1224206 a la API.
# Datos enviados exitosamente para fixture 1224207 a la API.
# Datos enviados exitosamente para fixture 1224208 a la API.
# Datos enviados exitosamente para fixture 1224209 a la API.
# Datos enviados exitosamente para fixture 1224210 a la API.
# Datos enviados exitosamente para fixture 1224211 a la API.
# Datos enviados exitosamente para fixture 1224212 a la API.
# Datos enviados exitosamente para fixture 1224213 a la API.
# Datos enviados exitosamente para fixture 1224214 a la API.
# Datos enviados exitosamente para fixture 1224215 a la API.
# Datos enviados exitosamente para fixture 1224216 a la API.
# Datos enviados exitosamente para fixture 1224217 a la API.
# Datos enviados exitosamente para fixture 1224218 a la API.
# Datos enviados exitosamente para fixture 1224219 a la API.
# Datos enviados exitosamente para fixture 1224220 a la API.
# Datos enviados exitosamente para fixture 1224221 a la API.
# Datos enviados exitosamente para fixture 1224222 a la API.
# Datos enviados exitosamente para fixture 1224223 a la API.
# Datos enviados exitosamente para fixture 1224224 a la API.
# Datos enviados exitosamente para fixture 1224225 a la API.
# Datos enviados exitosamente para fixture 1224226 a la API.
# Datos enviados exitosamente para fixture 1224227 a la API.
# Datos enviados exitosamente para fixture 1224228 a la API.
# Datos enviados exitosamente para fixture 1224229 a la API.
# Datos enviados exitosamente para fixture 1224230 a la API.
# Datos enviados exitosamente para fixture 1224231 a la API.
# Datos enviados exitosamente para fixture 1224232 a la API.
# Datos enviados exitosamente para fixture 1224233 a la API.
# Datos enviados exitosamente para fixture 1224234 a la API.
# Datos enviados exitosamente para fixture 1224235 a la API.
# Datos enviados exitosamente para fixture 1224236 a la API.
# Datos enviados exitosamente para fixture 1224237 a la API.
# Datos enviados exitosamente para fixture 1224238 a la API.
# Datos enviados exitosamente para fixture 1224239 a la API.
# Datos enviados exitosamente para fixture 1224240 a la API.
# Datos enviados exitosamente para fixture 1224241 a la API.
# Datos enviados exitosamente para fixture 1224242 a la API.
# Datos enviados exitosamente para fixture 1224243 a la API.
# Datos enviados exitosamente para fixture 1224244 a la API.
# Datos enviados exitosamente para fixture 1224245 a la API.
# Datos enviados exitosamente para fixture 1224246 a la API.
# Datos enviados exitosamente para fixture 1224247 a la API.
# Datos enviados exitosamente para fixture 1224248 a la API.
# Datos enviados exitosamente para fixture 1224249 a la API.
# Datos enviados exitosamente para fixture 1224250 a la API.
# Datos enviados exitosamente para fixture 1224251 a la API.
# Datos enviados exitosamente para fixture 1224252 a la API.
# Datos enviados exitosamente para fixture 1224253 a la API.
# Datos enviados exitosamente para fixture 1224254 a la API.
# Datos enviados exitosamente para fixture 1224255 a la API.
# Datos enviados exitosamente para fixture 1224256 a la API.
# Datos enviados exitosamente para fixture 1224257 a la API.
# Datos enviados exitosamente para fixture 1224258 a la API.
# Datos enviados exitosamente para fixture 1224259 a la API.
# Datos enviados exitosamente para fixture 1224260 a la API.
# Datos enviados exitosamente para fixture 1224261 a la API.
# Datos enviados exitosamente para fixture 1224262 a la API.
# Datos enviados exitosamente para fixture 1224263 a la API.
# Datos enviados exitosamente para fixture 1224264 a la API.
# Datos enviados exitosamente para fixture 1224265 a la API.
# Datos enviados exitosamente para fixture 1224266 a la API.
# Datos enviados exitosamente para fixture 1224267 a la API.
# Datos enviados exitosamente para fixture 1224268 a la API.
# Datos enviados exitosamente para fixture 1224269 a la API.
# Datos enviados exitosamente para fixture 1224270 a la API.
# Datos enviados exitosamente para fixture 1224271 a la API.
# Datos enviados exitosamente para fixture 1224272 a la API.
# Datos enviados exitosamente para fixture 1224273 a la API.
# Datos enviados exitosamente para fixture 1224274 a la API.
# Datos enviados exitosamente para fixture 1224275 a la API.
# Datos enviados exitosamente para fixture 1224276 a la API.
# Datos enviados exitosamente para fixture 1224277 a la API.
# Datos enviados exitosamente para fixture 1224278 a la API.
# Datos enviados exitosamente para fixture 1224279 a la API.
# Datos enviados exitosamente para fixture 1224280 a la API.
